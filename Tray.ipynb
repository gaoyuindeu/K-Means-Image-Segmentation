# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import numpy as np
from sklearn.cluster import KMeans
from PIL import Image
from skimage.color import rgb2hsv

# %%
img = Image.open(r'D:\Downloads\tray-food-segmentation\TrayDataset\TrayDataset\XTest\2002a.jpg')

# %%
x = np.array(img)

# %%
imshow(x)

# %%
z = np.dstack((x,rgb2hsv(x)))

# %%
z.shape
# Out:
# (256, 416, 6)

# %%
vectorized = np.float32(z.reshape((-1,6)))

# %%
kmeans = KMeans(random_state=32, init='random', n_clusters=7)

# %%
james = kmeans.fit_predict(vectorized)

# %%
pic = james.reshape(256,416)

# %%
imshow(pic)

# %%
f, axarr = plt.subplots(1,2,figsize=(15,15))
axarr[0].set_xlabel('Original Image', fontsize=20)
axarr[1].set_xlabel('Segmented Image', fontsize=20)  
axarr[0].imshow(x)
axarr[1].imshow(pic)

# %%
f.savefig(r"D:\Downloads\tray-food-segmentation\image.png")
